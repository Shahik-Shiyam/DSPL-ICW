# %% [markdown]
# <a href="https://colab.research.google.com/github/Shahik-Shiyam/DSPL-ICW/blob/main/Data_Preprocessing_DSPL_ICW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = "/content/UNdata_Export_20250422_214745039.csv"

pd.read_csv(df)
# Out:
#                OID Country or Area  Year                   Description  \
# 0    52460C..ZF...       SRI LANKA  2008            TREASURY BILL RATE
# 1    52460P..ZF...       SRI LANKA  2008        MINIMUM UNSECURED RATE
# 2    52460B..ZF...       SRI LANKA  2008          INTERBANK CALL LOANS
# 3    52460L..ZF...       SRI LANKA  2008  FIXED DEPOSITS:3-MONTH (MAX)
# 4    52460...ZF...       SRI LANKA  2008  ADVANCE RATE (END OF PERIOD)
# ..             ...             ...   ...                           ...
# 173  52460...ZF...       SRI LANKA  1954  ADVANCE RATE (END OF PERIOD)
# 174  52460...ZF...       SRI LANKA  1953  ADVANCE RATE (END OF PERIOD)
# 175  52460...ZF...       SRI LANKA  1952  ADVANCE RATE (END OF PERIOD)
# 176  52460...ZF...       SRI LANKA  1951  ADVANCE RATE (END OF PERIOD)
# 177  52460...ZF...       SRI LANKA  1950  ADVANCE RATE (END OF PERIOD)
#
#             Magnitude    Value
# 0    PERCENT PER ANNU  18.9142
# 1    PERCENT PER ANNU  18.8917
# ...

# %%
df = pd.read_csv(file_path)

# Now you can perform operations on the DataFrame
df = df.drop(columns=['OID', 'Magnitude', 'Country or Area'])

df.head()
# Out:
#    Year                   Description    Value
# 0  2008            TREASURY BILL RATE  18.9142
# 1  2008        MINIMUM UNSECURED RATE  18.8917
# 2  2008          INTERBANK CALL LOANS  21.2233
# 3  2008  FIXED DEPOSITS:3-MONTH (MAX)  10.8892
# 4  2008  ADVANCE RATE (END OF PERIOD)  15.0000

# %%
#Data exploration
dtype = df.dtypes
print(dtype)
# Out:
# Year             int64
# Description     object
# Value          float64
# dtype: object

# %%
duplicate_rows = df[df.duplicated()]

# Print the number of duplicate rows
print(f"Number of duplicate rows: {len(duplicate_rows)}")
# Out:
# Number of duplicate rows: 0

# %%
null_counts = df.isnull().sum()

# Print the null counts for each column
print("Null Value Counts per Column:")
print(null_counts)
# Out:
# Null Value Counts per Column:
# Year           0
# Description    0
# Value          0
# dtype: int64

# %%
total_nulls = df.isnull().sum().sum()
print(f"\nTotal Null Values in DataFrame: {total_nulls}")
# Out:
# Total Null Values in DataFrame: 0

# %%
df.to_csv("Interest_Rates.csv", index=False)

# %%
#feature engineering

# Step 1: Load your Excel or CSV file
file_path = '/content/Interest_Rates.csv'  # update if needed
df = pd.read_csv(file_path)

# Step 2: Define the rules for Risk Level
def assign_risk(description):
    if 'TREASURY BILL RATE' in description or 'FIXED DEPOSITS:3-MONTH (MAX)' in description:
        return 'Low'
    elif 'MINIMUM UNSECURED RATE' in description:
        return 'Medium'
    elif 'INTERBANK CALL LOANS' in description:
        return 'High'
    elif 'ADVANCE RATE (END OF PERIOD)' in description:
        return 'Medium'
    else:
        return 'Unknown'

# Step 3: Define the rules for Sector Type
def assign_sector(description):
    if 'TREASURY BILL RATE' in description:
        return 'Government'
    elif 'FIXED DEPOSITS:3-MONTH (MAX)' in description:
        return 'Private'
    elif 'MINIMUM UNSECURED RATE' in description or 'INTERBANK CALL LOANS' in description:
        return 'Private'
    elif 'ADVANCE RATE (END OF PERIOD)' in description:
        return 'Government'
    else:
        return 'Unknown'

# Step 4: Apply the rules
df['Risk Level'] = df['Description'].apply(assign_risk)
df['Sector Type'] = df['Description'].apply(assign_sector)

# Step 5: Save the updated file
output_path = '/content/Interest_Rates.csv'
df.to_excel(output_path, index=False)

print(f"Done! Your updated file is saved here: {output_path}")
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/io/excel/_base.py in __new__(cls, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs)
#    1135                 try:
# -> 1136                     engine = config.get_option(f"io.excel.{ext}.writer", silent=True)
#    1137                     if engine == "auto":
#
# /usr/local/lib/python3.11/dist-packages/pandas/_config/config.py in __call__(self, *args, **kwds)
#     273     def __call__(self, *args, **kwds) -> T:
# --> 274         return self.__func__(*args, **kwds)
#     275
#
# /usr/local/lib/python3.11/dist-packages/pandas/_config/config.py in _get_option(pat, silent)
#     145 def _get_option(pat: str, silent: bool = False) -> Any:
# --> 146     key = _get_single_key(pat, silent)
#     147
#
# ...

# %%
#feature engineering

# Step 1: Load your Excel or CSV file
file_path = '/content/Interest_Rates.csv'  # update if needed
df = pd.read_csv(file_path)

# Step 2: Define the rules for Risk Level
def assign_risk(description):
    if 'TREASURY BILL RATE' in description or 'FIXED DEPOSITS:3-MONTH (MAX)' in description:
        return 'Low'
    elif 'MINIMUM UNSECURED RATE' in description:
        return 'Medium'
    elif 'INTERBANK CALL LOANS' in description:
        return 'High'
    elif 'ADVANCE RATE (END OF PERIOD)' in description:
        return 'Medium'
    else:
        return 'Unknown'

# Step 3: Define the rules for Sector Type
def assign_sector(description):
    if 'TREASURY BILL RATE' in description:
        return 'Government'
    elif 'FIXED DEPOSITS:3-MONTH (MAX)' in description:
        return 'Private'
    elif 'MINIMUM UNSECURED RATE' in description or 'INTERBANK CALL LOANS' in description:
        return 'Private'
    elif 'ADVANCE RATE (END OF PERIOD)' in description:
        return 'Government'
    else:
        return 'Unknown'

# Step 4: Apply the rules
df['Risk Level'] = df['Description'].apply(assign_risk)
df['Sector Type'] = df['Description'].apply(assign_sector)

# Step 5: Save the updated file
output_path = '/content/Interest_Rates.xlsx' # Changed the file extension to .xlsx
df.to_excel(output_path, index=False) # Now using to_excel with the appropriate file extension

print(f"Done! Your updated file is saved here: {output_path}")
# Out:
# Done! Your updated file is saved here: /content/Interest_Rates.xlsx
